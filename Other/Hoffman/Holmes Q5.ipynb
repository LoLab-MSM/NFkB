# %%
# %pwd
# Out:
# u'/Users/geenaildefonso/Projects/NFkB/Hoffman'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x10y10 = np.loadtxt(open("holmes1010.csv", "rb"), delimiter=",")
x10y1 = np.loadtxt(open("holmes101.csv", "rb"), delimiter=",")
x1y10 = np.loadtxt(open("holmes110.csv", "rb"), delimiter=",")
x1y1 = np.loadtxt(open("holmes11.csv", "rb"), delimiter=",")

x10y10b = np.loadtxt(open("holmes1010b.csv", "rb"), delimiter=",")
x10y1b = np.loadtxt(open("holmes101b.csv", "rb"), delimiter=",")
x1y10b = np.loadtxt(open("holmes110b.csv", "rb"), delimiter=",")
x1y1b = np.loadtxt(open("holmes11b.csv", "rb"), delimiter=",")

x10y10a = np.loadtxt(open("holmes1010a.csv", "rb"), delimiter=",")
x10y1a = np.loadtxt(open("holmes101a.csv", "rb"), delimiter=",")
x1y10a = np.loadtxt(open("holmes110a.csv", "rb"), delimiter=",")
x1y1a = np.loadtxt(open("holmes11a.csv", "rb"), delimiter=",")

x10y10i = np.loadtxt(open("holmes101i.csv", "rb"), delimiter=",")
x10y1i = np.loadtxt(open("holmes101i.csv", "rb"), delimiter=",")
x1y10i = np.loadtxt(open("holmes110i.csv", "rb"), delimiter=",")
x1y1i = np.loadtxt(open("holmes11i.csv", "rb"), delimiter=",")

# %%
plt.figure()

plt.plot(x10y10[0,:], x10y10[1,:])
plt.plot(x10y1[0,:], x10y1[1,:])
plt.plot(x1y10[0,:], x1y10[1,:])
plt.plot(x1y1[0,:], x1y1[1,:])
plt.xlabel("x", fontsize=16)
plt.ylabel("y", fontsize=16)
plt.ylim(ymin = 0, ymax =11)
plt.xlim(xmin = 0, xmax = 11)
plt.title('Equilibrium Analysis X vs. Y')
# plt.plot(datax, datay)

# %%
fig = plt.figure(figsize=(17,5))
# fig.subplots_adjust(wspace = 1, hspace = 0.1)
ax1 = fig.add_subplot(1,4,1)
ax2 = fig.add_subplot(1,4,2)
ax3 = fig.add_subplot(1,4,3)
ax4 = fig.add_subplot(1,4,4)

# ax1.plot(x10y10[0,:], 'r-', label='x')
# ax1.plot(x10y10[1,:], 'b-', label='y')
# ax1.plot(x10y10[0,:], 'r-', label='x')
# ax1.plot(x10y10[1,:], 'b-', label='y')

ax1.plot(x10y10[0,:], x10y10[1,:])
ax1.plot(x10y1[0,:], x10y1[1,:])
ax1.plot(x1y10[0,:], x1y10[1,:])
ax1.plot(x1y1[0,:], x1y1[1,:])
#ax1.plot(z, 'g-', label='prey')
ax1.set_title("X10 vs Y10")
ax1.set_xlabel("x")
ax1.set_ylabel("y")
# ax1.grid()
ax1.legend(loc='best')

ax2.plot(x10y1[0,:], 'r-', label='x')
ax2.plot(x10y1[1,:], 'b-', label='y')
ax2.set_title("X10 vs Y1")
ax2.set_xlabel("x")
ax2.set_ylabel("y")  
# ax2.set_title("X10 vs Y10 (b = 1)")

ax3.plot(x1y10[0,:], 'r-', label='x')
ax3.plot(x1y10[1,:], 'b-', label='y')
#ax1.plot(z, 'g-', label='prey')
ax3.set_title("X1 vs Y10")
ax3.set_xlabel("x")
ax3.set_ylabel("y")
# ax3.grid()
ax3.legend(loc='best')

ax4.plot(x1y1[0,:], 'r-', label='x')
ax4.plot(x1y1[1,:], 'b-', label='y')
#ax1.plot(z, 'g-', label='prey')
ax4.set_title("X1 vs Y1")
ax4.set_xlabel("x")
ax4.set_ylabel("y")
# ax4.g?rid()
ax4.legend(loc='best')

plt.tight_layout()

# %%
x10y10b = np.loadtxt(open("holmes1010b.csv", "rb"), delimiter=",")
x10y1b = np.loadtxt(open("holmes101b.csv", "rb"), delimiter=",")
x1y10b = np.loadtxt(open("holmes110b.csv", "rb"), delimiter=",")
x1y1b = np.loadtxt(open("holmes11b.csv", "rb"), delimiter=",")

# %%
plt.figure()
plt.plot(x10y10b[0,:], x10y10b[1,:])
plt.plot(x10y1b[0,:], x10y1b[1,:])
plt.plot(x1y10b[0,:], x1y10b[1,:])
plt.plot(x1y1b[0,:], x1y1b[1,:])
plt.xlabel("x", fontsize=16)
plt.ylabel("y", fontsize=16)
plt.ylim(ymin = 0, ymax =11)
plt.xlim(xmin = 0, xmax = 11)
plt.title('Equilibrium Analysis(b = 1) X vs. Y')

# %%
fig = plt.figure(figsize=(15,5))
# fig.subplots_adjust(wspace = 1, hspace = 0.1)
ax1 = fig.add_subplot(1,4,1)
ax2 = fig.add_subplot(1,4,2)
ax3 = fig.add_subplot(1,4,3)
ax4 = fig.add_subplot(1,4,4)

ax1.plot(x10y10b[0,:], 'r-', label='x')
ax1.plot(x10y10b[1,:], 'b-', label='y')
#ax1.plot(z, 'g-', label='prey')
ax1.set_title("X10 vs Y10 (b = 1)")
ax1.set_xlabel("x")
ax1.set_ylabel("y")
# ax1.grid()
ax1.legend(loc='best')

ax2.plot(x10y1b[0,:], 'r-', label='x')
ax2.plot(x10y1b[1,:], 'b-', label='y')
ax2.set_title("X10 vs Y1 (a = 0.5)")
ax2.set_xlabel("x")
ax2.set_ylabel("y")  
ax2.set_title("X10 vs Y10 (b = 1)")

ax3.plot(x1y10b[0,:], 'r-', label='x')
ax3.plot(x1y10b[1,:], 'b-', label='y')
#ax1.plot(z, 'g-', label='prey')
ax3.set_title("X1 vs Y10 (b = 1)")
ax3.set_xlabel("x")
ax3.set_ylabel("y")
# ax3.grid()
ax3.legend(loc='best')

ax4.plot(x1y1b[0,:], 'r-', label='x')
ax4.plot(x1y1b[1,:], 'b-', label='y')
#ax1.plot(z, 'g-', label='prey')
ax4.set_title("X1 vs Y1 (b = 1)")
ax4.set_xlabel("x")
ax4.set_ylabel("y")
# ax4.g?rid()
ax4.legend(loc='best')

plt.tight_layout()

# %%
x10y10a = np.loadtxt(open("holmes1010a.csv", "rb"), delimiter=",")
x10y1a = np.loadtxt(open("holmes101a.csv", "rb"), delimiter=",")
x1y10a = np.loadtxt(open("holmes110a.csv", "rb"), delimiter=",")
x1y1a = np.loadtxt(open("holmes11a.csv", "rb"), delimiter=",")
print(1010)
print(x10y10a[0,:][-1])
print(x10y10a[1,:][-1])
print(101)
print(x10y1a[0,:][-1])
print(x10y1a[1,:][-1])
print(110)
print(x1y10a[0,:][-1])
print(x1y10a[1,:][-1])
print(11)
print(x1y1a[0,:][-1])
print(x1y1a[1,:][-1])
# Out:
# 1010
# 0.0204791303883
# 2.49488021452
# 101
# 2.49488021534
# 0.0204791358796
# 110
# 0.0204791358796
# 2.49488021534
# 11
# 1.0903297534
# 1.09032975335

# %%
plt.figure()
plt.plot(x10y10a[0,:],x10y10a[1,:])
plt.plot(x10y1a[0,:], x10y1a[1,:])
plt.plot(x1y10a[0,:], x1y10a[1,:])
plt.plot(x1y1a[0,:], x1y1a[1,:])
plt.xlabel("x", fontsize=16)
plt.ylabel("y", fontsize=16)
plt.ylim(ymin = -1, ymax =11)
plt.xlim(xmin = -1, xmax = 11)
plt.title('Equilibrium Analysis(a = 0.5) X vs. Y')

# %%
fig = plt.figure(figsize=(15,5))
# fig.subplots_adjust(wspace = 1, hspace = 0.1)
ax1 = fig.add_subplot(1,4,1)
ax2 = fig.add_subplot(1,4,2)
ax3 = fig.add_subplot(1,4,3)
ax4 = fig.add_subplot(1,4,4)

ax1.plot(x10y10a[0,:], 'r-', label='x')
ax1.plot(x10y10a[1,:], 'b-', label='y')
#ax1.plot(z, 'g-', label='prey')
ax1.set_title("X10 vs Y10 (a = 0.5)")
ax1.set_xlabel("x")
ax1.set_ylabel("y")
# ax1.grid()
ax1.legend(loc='best')

ax2.plot(x10y1a[0,:], 'r-', label='x')
ax2.plot(x10y1a[1,:], 'b-', label='y')
ax2.set_title("X10 vs Y1 (a = 0.5)")
ax2.set_xlabel("x")
ax2.set_ylabel("y")  
ax2.set_title("X10 vs Y10 (a = 0.5)")

ax3.plot(x1y10a[0,:], 'r-', label='x')
ax3.plot(x1y10a[1,:], 'b-', label='y')
#ax1.plot(z, 'g-', label='prey')
ax3.set_title("X1 vs Y10 (a = 0.5)")
ax3.set_xlabel("x")
ax3.set_ylabel("y")
# ax3.grid()
ax3.legend(loc='best')

ax4.plot(x1y1a[0,:], 'r-', label='x')
ax4.plot(x1y1a[1,:], 'b-', label='y')
#ax1.plot(z, 'g-', label='prey')
ax4.set_title("X1 vs Y1 (a = 0.5)")
ax4.set_xlabel("x")
ax4.set_ylabel("y")
# ax4.g?rid()
ax4.legend(loc='best')

plt.tight_layout()
# ax2.grid()

# %%
x10y10i = np.loadtxt(open("holmes101i.csv", "rb"), delimiter=",")
x10y1i = np.loadtxt(open("holmes101i.csv", "rb"), delimiter=",")
x1y10i = np.loadtxt(open("holmes110i.csv", "rb"), delimiter=",")
x1y1i = np.loadtxt(open("holmes11i.csv", "rb"), delimiter=",")
print(1010)
print(x10y10i[0,:][-1])
print(x10y10i[1,:][-1])
print(101)
print(x10y1i[0,:][-1])
print(x10y1i[1,:][-1])
print(110)
print(x1y10i[0,:][-1])
print(x1y10i[1,:][-1])
print(11)
print(x1y1i[0,:][-1])
print(x1y1i[1,:][-1])
# Out:
# 1010
# 1.94842010276
# 1.94841964392
# 101
# 1.94842010276
# 1.94841964392
# 110
# 1.94841964558
# 1.94842010223
# 11
# 1.9484198653
# 1.9484198653

# %%
plt.figure()
plt.plot(x10y10i[0,:],x10y10i[1,:])
plt.plot(x10y1i[0,:], x10y1i[1,:])
plt.plot(x1y10i[0,:], x1y10i[1,:])
plt.plot(x1y1i[0,:], x1y1i[1,:])
plt.xlabel("x", fontsize=16)
plt.ylabel("y", fontsize=16)
plt.ylim(ymin = 0, ymax = 11)
plt.xlim(xmin = 0, xmax = 11)
plt.title('Equilibrium Analysis(I = 0.5) X vs. Y')

# %%
fig = plt.figure(figsize=(15,5))
# fig.subplots_adjust(wspace = 1, hspace = 0.1)
ax1 = fig.add_subplot(1,4,1)
ax2 = fig.add_subplot(1,4,2)
ax3 = fig.add_subplot(1,4,3)
ax4 = fig.add_subplot(1,4,4)

ax1.plot(x10y10i[0,:], 'r-', label='x')
ax1.plot(x10y10i[1,:], 'b-', label='y')
#ax1.plot(z, 'g-', label='prey')
ax1.set_title("X10 vs Y10 (I = 0.5)")
ax1.set_xlabel("x")
ax1.set_ylabel("y")
# ax1.grid()
ax1.legend(loc='best')

ax2.plot(x10y1i[0,:], 'r-', label='x')
ax2.plot(x10y1i[1,:], 'b-', label='y')
ax2.set_title("X10 vs Y1 (I = 0.5)")
ax2.set_xlabel("x")
ax2.set_ylabel("y")  
ax2.set_title("X10 vs Y10 (a = 0.5)")

ax3.plot(x1y10i[0,:], 'r-', label='x')
ax3.plot(x1y10i[1,:], 'b-', label='y')
#ax1.plot(z, 'g-', label='prey')
ax3.set_title("X1 vs Y10 (I = 0.5)")
ax3.set_xlabel("x")
ax3.set_ylabel("y")
# ax3.grid()
ax3.legend(loc='best')

ax4.plot(x1y1i[0,:], 'r-', label='x')
ax4.plot(x1y1i[1,:], 'b-', label='y')
#ax1.plot(z, 'g-', label='prey')
ax4.set_title("X1 vs Y1 (I = 0.5)")
ax4.set_xlabel("x")
ax4.set_ylabel("y")
# ax4.g?rid()
ax4.legend(loc='best')

plt.tight_layout()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
b = 1 
g = 0.5 
d = 0.5 
n = 1
x = 50
y = np.linspace(0,20,100)
x1 = b + g*(x**n/(1+x**n))
x2 = d*x
plt.plot([0,60], 1 + 0.5*(50/(1+50)))
# plt.plot(x2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-56f79ff846bc> in <module>()
#      11 x1 = b + g*(x**n/(1+x**n))
#      12 x2 = d*x
# ---> 13 plt.plot([0,60], 1 + 0.5*(50/(1+50)))
#      14 # plt.plot(x2)
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    2985         ax.hold(hold)
#    2986     try:
# -> 2987         ret = ax.plot(*args, **kwargs)
#    2988         draw_if_interactive()
#    2989     finally:
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/axes.pyc in plot(self, *args, **kwargs)
#    4135         lines = []
#    4136
# -> 4137         for line in self._get_lines(*args, **kwargs):
#    4138             self.add_line(line)
#    4139             lines.append(line)
#
# ...

# %%
# import necessary libraries
import matplotlib.pyplot as plt
# show plots in notebook
% matplotlib inline

# define system in terms of separated differential equations
def f(x,y):
    return -((17.38 + 869*x**2)/(1 + x**2 + y**2) - 11*x)
def g(x,y):
    return -((.869 + 43.45*x**2)/(1 + x**2) - y)

# initialize lists containing values
x = []
y = []

#iv1, iv2 = initial values, dt = timestep, time = range
def sys(iv1, iv2, dt, time):
    # initial values:
    x.append(iv1)
    y.append(iv2)
    #z.append(iv3)
    # compute and fill lists
    for i in range(time):
        x.append(x[i] + (f(x[i],y[i])) * dt)
        y.append(y[i] + (g(x[i],y[i])) * dt)
        #z.append(z[i] + (h(x[i],y[i],z[i])) * dt)
    return x, y

sys(20, 20, 0.01, 100)

print(x)
print(y)
#plot
fig = plt.figure(figsize=(15,5))
fig.subplots_adjust(wspace = 0.5, hspace = 0.3)
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.plot(x, y, 'r-')
# ax1.plot(y, x 'b-', label='prey')
#ax1.plot(z, 'g-', label='prey')
ax1.set_title("Dynamics in time")
ax1.set_xlabel("x")
ax1.set_ylabel("y")
# ax1.grid()
ax1.legend(loc='best')

ax2.plot(x, y, color="blue")
ax2.set_xlabel("x")
ax2.set_ylabel("y")  
ax2.set_title("Phase space")
# Out:
# [20, 17.860207490636704, 15.924231739473925, 14.211048634743644, 12.72285652762591, 11.447420552274226, 10.362954198311417, 9.443394548257528, 8.662501415462499, 7.996295116425594, 7.424101312987429, 6.928708701840124, 6.496075677935123, 6.1148677087708565, 5.775975992507309, 5.472084163117063, 5.197304397696705, 4.946882841681776, 4.716965801077767, 4.504415986202281, 4.306668644711891, 4.121618927805148, 3.947533495329258, 3.7829808656890025, 3.626776260166348, 3.4779376785050835, 3.3356507078766975, 3.199240152833025, 3.0681470187783413, 2.9419097186327474, 2.8201486277158687, 2.702553305517136, 2.5888718501761865, 2.478901963663289, 2.3724833914683625, 2.2694914665965906, 2.169831538779115, 2.0734341098422493, 1.9802505281080713, 1.8902491208862409, 1.8034116664730506, 1.7197301271517393, 1.6392035837181005, 1.5618353309294637, 1.4876301124894622, 1.4165914937526587, 1.348719389720651, 1.2840077839712563, 1.222442689250946, 1.1640004105724746, 1.1086461748186323, 1.05633318557118
# ...

# %%
import numpy as np  
import matplotlib.pyplot as plt  
def graph(formula, x_range):  
    x = np.array(x_range)  
    y = eval(formula)
    plt.plot(x, y)  
    plt.show()

# %%
graph('0.5*x**4/(1+x**4)', range(0, 5))

# %%
graph('0.5*x', range(0, 50))
